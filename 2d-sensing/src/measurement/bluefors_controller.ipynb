# %%
from BlueforsController import BlueFTController

# %%
API_KEY = '7768e503-165b-407c-b54d-a4dac3cc4088' 
IP_ADDRESS = '10.32.83.100'
PORT_NUMBER = 49098
MXC_ID = 6
MXC_HEATER_ID = 4

controller = BlueFTController(ip=IP_ADDRESS, port=PORT_NUMBER, key=API_KEY, mixing_chamber_channel_id=MXC_ID,mixing_chamber_heater_id=MXC_HEATER_ID)

# %%
controller.get_mxc_temperature()
controller.get_mxc_heater_setpoint()
# Out:
# 2026-09-08 15:30:37,385 :-- INFO --: Requesting value: temperature  from channel 6
# 2026-09-08 15:30:37,385 :-- INFO --: Requesting value: temperature  from channel 6
# c:\Users\eseye\anaconda3\envs\BoettcherBase\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.32.83.100'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\eseye\anaconda3\envs\BoettcherBase\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.32.83.100'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 0.0

# %%
controller.get_mxc_heater_setpoint()
# Out:
# c:\Users\eseye\anaconda3\envs\BoettcherBase\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.32.83.100'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2e-08

# %%
controller.set_mxc_heater_setpoint(10)
# Out:
# 2026-09-08 15:34:23,681 :-- INFO --: Mixing Chamber Heater: Setting setpoint to 0.01
# 2026-09-08 15:34:23,681 :-- INFO --: Mixing Chamber Heater: Setting setpoint to 0.01
# c:\Users\eseye\anaconda3\envs\BoettcherBase\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.32.83.100'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 2026-09-08 15:34:23,845 :-- INFO --: Mixing Chamber Heater: Applying settings
# 2026-09-08 15:34:23,845 :-- INFO --: Mixing Chamber Heater: Applying settings
# c:\Users\eseye\anaconda3\envs\BoettcherBase\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.32.83.100'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
# ...
